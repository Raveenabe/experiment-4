# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pylab as plot

params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plot.rcParams.update(params)

x1=np.array([395,460,540,630])
y1=[0.014158,0.102884,0.145115,0.005157]

#1st
plt.figure(figsize=(30,15))
plt.plot(x1,y1,label='1st drop',  marker='*')

#2nd
y2=[0.019047,0.125291,0.166009,0.006182]
plt.plot(x1,y2,label='2nd drop',  marker='*')

#3rd
y3=[0.024682,0.131064,0.171079,0.006182]
plt.plot(x1,y3,label='3rd drop',  marker='*')

#4th
y4=[-0.043599,0.133663,0.174778,0.100019]
plt.plot(x1,y4,label='4th drop',  marker='*')

#5th
y5=[0.046518,0.138558,0.181822,0.016793]
plt.plot(x1,y5,label='5th drop',  marker='*')

#6th
y6=[0.042669,0.135043,0.177313,0.015794]
plt.plot(x1,y6,label='6th drop',  marker='*')

#7th
y7=[0.044994,0.134957,0.178705,0.020892]
plt.plot(x1,y7,label='7th drop',  marker='*')

#8th
y8=[0.048037,0.135731,0.180267,0.026420]
plt.plot(x1,y8,label='8th drop',  marker='*')

#9th
y9=[0.049550,0.134957,0.180007,0.030429]
plt.plot(x1,y9,label='9th drop',  marker='*')

#10th
y10=[0.049550,0.141622,0.186456,0.037269]
plt.plot(x1,y10,label='10th drop',marker='*')


plt.legend()
plt.ylabel('Absorbance', fontsize=25)
plt.xlabel('Wavelength (nm)' ,fontsize=25)
plt.title('Graph of Absorbance vs Wavelenght (nm) ' ,fontsize=30)
plt.grid() 
plt.xticks(size = 20)
plt.yticks(size = 20)
# Out:
# (array([-0.1 , -0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
