# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pylab as plot

params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plot.rcParams.update(params)

x1=np.array([395,460,540,630])
y1=[1.087542,0.993645,0.989666,0.997999]

#1st
plt.figure(figsize=(30,15))
plt.plot(x1,y1,label='1st drop',  marker='*')

#2nd
y2=[1.065241,0.9911676,0.988096,0.996014]
plt.plot(x1,y2,label='2nd drop',  marker='*')

#3rd
y3=[1.075642,0.992463,0.990453,0.994827]
plt.plot(x1,y3,label='3rd drop',  marker='*')

#4th
y4=[1.051257,0.992463,0.987704,0.997204]
plt.plot(x1,y4,label='4th drop',  marker='*')


#5th
y5=[1.037634,0.985815,0.982639,0.990694]
plt.plot(x1,y5,label='5th drop',  marker='*')

#6th
y6=[1.016129,0.991676,0.987704,0.996410]
plt.plot(x1,y6,label='6th drop',  marker='*')

#7th
y7=[1.026882,0.992266,0.988488,0.994234]
plt.plot(x1,y7,label='7th drop',  marker='*')

#8th
y8=[1.032258,0.989911,0.985554,0.992461]
plt.plot(x1,y8,label='8th drop',  marker='*')

#9th
y9=[1.032258,0.990498,0.986726,0.988933]
plt.plot(x1,y9,label='9th drop',  marker='*')

#10th
y10=[1.037634,0.977725,0.973994,0.980799]
plt.plot(x1,y10,label='10th drop',marker='*')


plt.legend()
plt.ylabel('Scattering value', fontsize=25)
plt.xlabel('Wavelength (nm)' ,fontsize=25)
plt.title('Graph of scattering value vs Wavelenght (nm) ' ,fontsize=30)
plt.grid() 
plt.xticks(size = 20)
plt.yticks(size = 20)
# Out:
# (array([0.96, 0.98, 1.  , 1.02, 1.04, 1.06, 1.08, 1.1 ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
