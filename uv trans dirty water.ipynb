# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab as plot

params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plot.rcParams.update(params) 
city=['Dirty pond water','Filtered pond water','Dirty water','Filtered dirty water']
#Gender=['Transmittence','Absorption*10',]
pos = np.arange(len(city))
bar_width = 0.2
red=[0.960893,0.963585,0.934782,0.971751]
green=[0.17324,0.16109,0.29289,0.12444]
#x1=np.array([1,2,3,4])

plt.figure(figsize=(20,10))
#trans

plt.scatter(pos,red,label='Observed value for transmittence',  color='red',marker='*',s=500)
a, b = np.polyfit(pos, red, 1)
#plt.plot(pos, a*pos+b, color='red', linestyle='--', linewidth=2,label='Best fit line of transmittence')

#absor
plt.scatter(pos,green,label='Observed value for absorbance',  color='green',marker='*',s=500)
a1, b1 = np.polyfit(pos, green, 1)
#plt.plot(pos, a1*pos+b1, color='green', linestyle='--', linewidth=2,label='Best fit line of absorbance')

#plt.bar(pos,red,bar_width,color='red',edgecolor='black')
#plt.bar(pos+bar_width,green,bar_width,color='green',edgecolor='black')
#plt.bar(pos+bar_width+bar_width,blue,bar_width,color='blue',edgecolor='black')
plt.xticks(pos, city)
plt.xlabel('Sample type', fontsize=25)
plt.ylabel('both transmittence and absorbance values', fontsize=25)
plt.title(' both transmittence and absorbance values w.r.t water type',fontsize=30)
plt.grid()
plt.legend()
plt.xticks(size = 20)
plt.yticks(size = 20)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
